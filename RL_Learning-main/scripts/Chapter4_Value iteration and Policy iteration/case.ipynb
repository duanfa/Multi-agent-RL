# %%
import gymnasium as gym
from gymnasium import spaces

# 创建Discrete对象
discrete_space = spaces.Discrete(5, seed=42)

# 查看核心属性
print("离散值总数 n:", discrete_space.n)          # 输出：5
print("数据类型 dtype:", discrete_space.dtype)    # 输出：int64
print("空间形状 shape:", discrete_space.shape)    # 输出：()
print("是否包含值3:", discrete_space.contains(3)) # 输出：True
print("是否包含值5:", discrete_space.contains(5)) # 输出：False

# 随机采样（种子42，首次采样结果固定为2）
print("随机采样结果:", discrete_space.sample())  # 输出：2
# print("随机采样结果:", discrete_space.sample())  # 输出：2
# print("随机采样结果:", discrete_space.sample())  # 输出：2
# print("随机采样结果:", discrete_space.sample())  # 输出：2
# print("随机采样结果:", discrete_space.sample())  # 输出：2
# print("随机采样结果:", discrete_space.sample())  # 输出：2


print("self.action_space:{}, self.action_space_size:{}".format(discrete_space, discrete_space.n))  #从0开始索引
# Out:
# 离散值总数 n: 5
# 数据类型 dtype: int64
# 空间形状 shape: ()
# 是否包含值3: True
# 是否包含值5: False
# 随机采样结果: 0
# self.action_space:Discrete(5), self.action_space_size:5
